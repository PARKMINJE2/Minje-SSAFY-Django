# %% [markdown]
# # Django

# %% [markdown]
# ## # Web Application

# %% [markdown]
# - Client(클라이언트):
#
# 	- '서비스를 요청'하는 주체(웹 사용자의 인터넷이 연결된 장치, 웹 브라우저).
#
# - Server(서버):
#
# 	- 클라이언트의 요청에 응답(페이지, 로직, 파일 등)하는 주체(웹 페이지, 앱을 저장하는 컴퓨터).

# %% [markdown]
# #### < 우리가 웹 페이지를 보게 되는 과정 >
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### < 웹 개발에서의 Frontend와 Backend >
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## # Framework

# %% [markdown]
# ### # Django

# %% [markdown]
# - 다양성
#
# 	- Python 기반으로 웹, 모바일 앱 백엔드, API 서버 및 빅데이터 관리 등 광범위한 서비스 개발에 적합
#
# - 확장성
#
# 	- 대량의 데이터에 대해 빠르고 유연하게 확장할 수 있는 기능을 제공
#
# - 보안
#
# 	- 취약점으로부터 보호하는 보안 기능이 기본적으로 내장되어 있음
#
# - 커뮤니티 지원
#
# 	- 개발자를 위한 지원, 문서 및 업데이트를 제공하는 활성화 된 커뮤니티

# %% [markdown]
# ## # ★가상 환경☆
#
# - Python 애플리케이션과 그에 따른 패키지들을 '격리'하여 관리할 수 있는 "독립적인" 실행 환경
#
# - 전역(global)은 더 이상 하지 않을 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ---
# ### 1. 가상 환경 venv 생성
#
# 	- venv 라는 이름의 가상환경 생성
#
# 	- 임의 이름으로 생성이 가능하나 관례적으로 'venv' 이름을 사용
#
# ![image.png](attachment:image.png)
#
# ---
# ### 2. 가상 환경 활성화
#
# 	- 활성화 명령어가 OS에 따라 다름에 주의하라
#
# 	- "in / out 개념이 아니라 on / off 개념이다"
#
# ![image-2.png](attachment:image-2.png)
#
# ---
# ### 3. 환경에 설치된 패키지 목록 확인
#
# ![image-3.png](attachment:image-3.png)
#
# ---
# ### 4. 설치된 패키지 목록 생성(1/2)
#
# 	- 현재 Python 환경에 설치된 모든 패키지와 그 버전을 텍스트 파일로 저장
#
# 	- requirements.txt: 생성된 파일 이름(관례적으로 사용)
#
# 	- 사용 시 주의사항
#
# 		- 활성화된 가상환경에서 실행해야 정확한 패키지 목록 생성
#
# 		- 시스템 전역 패키지와 구분 필요
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# * venv 파일(가상환경 자체)은 용량 문제로 공유하지 않는다. (requiremets.txt를 공유하면 되자너~)
#
# ---
# ### [번외] 패키지 목록 기반 설치
#
# 	- 생성된 requirements.txt로 다른 환경에서 동일한 환경 구성하기
#
# 	- 가상환경 활성화 후 requirements.txt에 작성된 목록을 기반으로 설치
#
# ![image-6.png](attachment:image-6.png)
#
# ---
# ### [번외] 비활성화
#
# ![image-7.png](attachment:image-7.png)
#
# ---

# %% [markdown]
# ### # 가상환경 주의사항 및 권장사항
#
# ![image.png](attachment:image.png)
#
# ---
# ---
#
# ### 1. Django 프로젝트 생성
#
# ![image-2.png](attachment:image-2.png)
#
# ### 2. Django 서버 실행
#
# ![image-3.png](attachment:image-3.png)
#
# ---

# %% [markdown]
# 앱을 사용하기 위한 순서
#
# 1. 앱 생성
#
# ![image.png](attachment:image.png)
#
# 2. 앱 등록
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# URLs -> View -> Template 순서로 하기
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
