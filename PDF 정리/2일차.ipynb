# %% [markdown]
# # Django2

# %% [markdown]
# ## # Template System

# %% [markdown]
# - 데이터 "표현"을 제어하면서, "표현"과 관련된 부분을 담당
#
# 	- 사용자에게 보여지는 부분

# %% [markdown]
# - HTML의 콘텐츠를 변수 값에 따라 변경하기
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## # Django Template Language(DTL)

# %% [markdown]
# - Template에서 조건, 반복, 변수 등의 프로그래밍적 기능을 제공하는 시스템

# %% [markdown]
# ### # DTL Syntax
#
# 1. Variable(변수)
#
# ![image-5.png](attachment:image-5.png)
#
# 2. Filters(필터)
#
# ![image-6.png](attachment:image-6.png)
#
# 3. Tags(태그)
#
# ![image-3.png](attachment:image-3.png)
#
# 4. Comments(주석)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## # 템플릿 상속(Template inheritance)

# %% [markdown]
# 1. 페이지의 공통 요소를 포함하고,
#
# 2. 하위 템플릿이 재정의 할 수 있는 공간을 정의하는 기본 'skeleton' 템플릿을 작성하여 상속 구조를 구축

# %% [markdown]
# ### # 상속 구조 만들기
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## # 상속 관련 DTL 태그

# %% [markdown]
# ### # 'extends' tag
#
# ![image.png](attachment:image.png)
#
# - 자식(하위) 템플릿이 부모 템플릿을 확장한다는 것을 알림
#
# 	- 반드시 자식 템플릿 최상단(가장 윗줄)에 작성되어야 한다.(2개 이상 사용 불가)

# %% [markdown]
# ### # 'block' tag
#
# ![image.png](attachment:image.png)
#
# - 하위 템플릿에서 재정의 할 수 있는 블록을 정의(상위 템플릿에 작성하며 하위 템플릿이 작성할 수 있는 공간을 지정하는 것)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ## # HTML form

# %% [markdown]
# ### # '요청'과 '응답'

# %% [markdown]
# #### # 데이터를 보내고 가져오기
#
# - HTML 'form' element를 통해 사용자와 애플리케이션 간의 상호작용 이해하기
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### # ★'form' element☆
#
# - 사용자로부터 할당된 데이터를 서버로 전송
#
# 	- 웹에서 사용자 정보를 입력하는 여러 방식(text, password, checkbox 등)을 제공

# %% [markdown]
# ---
# ---
#
# #### # Fake Naver 실습
#
# - https://search.naver.com/search.naver
# - ? ( 물음표를 기준으로 URL 주소와 쿼리스트링 파라미터를 구분한다)
# - where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8
#
# ---
#
# ![image.png](attachment:image.png)
#
# ---
#
# ![image-2.png](attachment:image-2.png)
#
# ---
#
# ![image-3.png](attachment:image-3.png)
#
# ---
#
# ![image-4.png](attachment:image-4.png)
#
# ---
# ---

# %% [markdown]
# ### # 'action' & 'method'
#
# - form의 핵심 속성 2가지
#
# 	- 데이터를 어디(action)로 어떤 방식(method)으로 요청할지

# %% [markdown]
# ### # 'input' element
#
# - 사용자의 데이터를 입력 받을 수 있는 요소(type 속성 값에 따라 다양한 유혀의 입력 데이터를 받음)
#
# 	- 핵심 속성: 'name'

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ---
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ---

# %% [markdown]
# ## # Django URLs

# %% [markdown]
# ### # URL dispatcher(분배기)
#
# - URL 패턴을 정의하고 해당 패턴이 일치하는 요청을 처리할 view 함수를 연결(매핑)

# %% [markdown]
# ### # Variable Routing
#
# - URL 일부에 변수를 포함시키는 것(변수는 view 함수의 인자로 전달 할 수 있음)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ## # App과 URL

# %% [markdown]
# ### # App URL mapping
#
# - 각 앱에 URL을 정의하는 것
#
# 	- 프로젝트와 각 앱이 URL을 나누어 관리를 편하게 하기 위함

# %% [markdown]
# ### # 2번째 앱 pages 생성 후 발생할 수 있는 문제
#
# - view 함수 이름이 같거나 같은 패턴의 URL 주소를 사용하게 되는 경우
#
# - 아래 코드와 같이 해결해 볼 수 있으나 더 좋은 방법이 필요
#
# ![image.png](attachment:image.png)
#
# -> "URL을 각자 app에서 관리하자"

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# (기존 urls.py)

# %% [markdown]
# ## # URL 이름 지정

# %% [markdown]
# ### # Naming URL patterns
#
# - URL에 이름을 지정하는 것(path 함수의 name 인자를 정의해서 사용)

# %% [markdown]
# #### # url 구조 변경에 따른 문제점
#
# - 기존 'articles/' 주소가 'articles/index/'로 변경됨에 따라 해당 url을 사용하는 모든 위치를 찾아가서 변경해야 함
#
# ![image.png](attachment:image.png)
#
# -> URL에 이름을 지어주고 이름만 기억하면 되지 않을까?

# %% [markdown]
# #### # Naming URL patterns 적용
#
# - path 함수의 name 키워드 인자를 정의
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### # URL 표기 변화
#
# - url을 작성하는 모든 곳에서 변경(a 태그의 href 속성 값 뿐만 아니라 form의 action 속성 등도 포함)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### # DTL URL tag

# %% [markdown]
# #### # 'url' tag
#
# - 주어진 url 패턴의 이름과 일치하는 절대 경로 주소를 반환
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## # URL 이름 공간

# %% [markdown]
# ### # app_name 속성
